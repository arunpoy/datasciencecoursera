# %%
import pandas as pd

# %%
nba_df = pd.read_csv("../data/nba_2013.csv")
nba_df.head()
# Out:
#           player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  ...  \
# 0     Quincy Acy  SF   23          TOT  63   0   847   66   141  0.468  ...
# 1   Steven Adams   C   20          OKC  81  20  1197   93   185  0.503  ...
# 2    Jeff Adrien  PF   27          TOT  53  12   961  143   275  0.520  ...
# 3  Arron Afflalo  SG   28          ORL  73  73  2552  464  1011  0.459  ...
# 4  Alexis Ajinca   C   25          NOP  56  30   951  136   249  0.546  ...
#
#    drb  trb  ast  stl  blk  tov   pf   pts     season  season_end
# 0  144  216   28   23   26   30  122   171  2013-2014        2013
# 1  190  332   43   40   57   71  203   265  2013-2014        2013
# 2  204  306   38   24   36   39  108   362  2013-2014        2013
# 3  230  262  248   35    3  146  136  1330  2013-2014        2013
# 4  183  277   40   23   46   63  187   328  2013-2014        2013
#
# [5 rows x 31 columns]

# %%
#find players from Golden state warriors
nba_df[nba_df['bref_team_id']=='GSW']
# Out:
#                 player pos  age bref_team_id   g  gs    mp   fg   fga    fg.  \
# 21    Hilton Armstrong   C   29          GSW  15   1    97    9    19  0.474
# 32     Harrison Barnes  SF   21          GSW  78  24  2204  271   679  0.399
# 55        Andrew Bogut   C   29          GSW  67  67  1769  235   375  0.627
# 110      Stephen Curry  PG   25          GSW  78  78  2846  652  1383  0.471
# 175     Draymond Green  SF   23          GSW  82  12  1797  187   459  0.407
# 216     Andre Iguodala  SF   30          GSW  63  63  2040  220   458  0.480
# 257      Ognjen Kuzmic   C   23          GSW  21   0    92    5    13  0.385
# 265          David Lee  PF   30          GSW  69  67  2288  513   981  0.523
# 327    Nemanja Nedovic  SG   22          GSW  24   0   142    8    39  0.205
# 334    Jermaine O'Neal  PF   35          GSW  44  13   883  125   248  0.504
# 405  Marreese Speights   C   26          GSW  79   3   982  195   442  0.441
# ...

# %%
#find shape of the data frame
nba_df.shape
# Out:
# (481, 31)

# %%
#find columns of the dataframe
nba_df.columns
# Out:
# Index(['player', 'pos', 'age', 'bref_team_id', 'g', 'gs', 'mp', 'fg', 'fga',
#        'fg.', 'x3p', 'x3pa', 'x3p.', 'x2p', 'x2pa', 'x2p.', 'efg.', 'ft',
#        'fta', 'ft.', 'orb', 'drb', 'trb', 'ast', 'stl', 'blk', 'tov', 'pf',
#        'pts', 'season', 'season_end'],
#       dtype='object')

# %%
#drop unwanted columns
nba_filtered_df =nba_df[['player','pos','age','bref_team_id','orb','drb','ast','stl','blk','pf','pts']]

# %%
nba_filtered_df.shape
# Out:
# (481, 11)

# %%
#find hte player who scored maximum points
max_pts=nba_filtered_df['pts'].max()
nba_filtered_df[nba_filtered_df['pts']==max_pts]
# Out:
#            player pos  age bref_team_id  orb  drb  ast  stl  blk   pf   pts
# 133  Kevin Durant  SF   25          OKC   58  540  445  103   59  174  2593

# %%
nba_filtered_df[0::2]
# Out:
#                     player pos  age bref_team_id  orb  drb  ast  stl  blk  \
# 0               Quincy Acy  SF   23          TOT   72  144   28   23   26
# 2              Jeff Adrien  PF   27          TOT  102  204   38   24   36
# 4            Alexis Ajinca   C   25          NOP   94  183   40   23   46
# 6        LaMarcus Aldridge  PF   28          POR  166  599  178   63   68
# 8                Ray Allen  SG   38          MIA   23  182  143   54    8
# 10         Al-Farouq Aminu  SF   23          NOP  129  367  114   82   38
# 12          Chris Andersen   C   35          MIA  129  250   19   32   97
# 14          James Anderson  SG   24          PHI   59  241  149   74   28
# 16   Giannis Antetokounmpo  SF   19          MIL   78  261  150   60   61
# 18            Joel Anthony   C   31          TOT   15   23    2    3   12
# 20            Trevor Ariza  SF   28          WAS   99  376  191  126   20
# 22          Darrell Arthur  SF   25          DEN   52  158   61   39   47
# ...

# %%
#set a column as an index
nba_index_df = nba_filtered_df.set_index('player')

# %%
#selecting a single row using iloc
nba_filtered_df.iloc[0]
# Out:
# player          Quincy Acy
# pos                     SF
# age                     23
# bref_team_id           TOT
# orb                     72
# drb                    144
# ast                     28
# stl                     23
# blk                     26
# pf                     122
# pts                    171
# Name: 0, dtype: object
