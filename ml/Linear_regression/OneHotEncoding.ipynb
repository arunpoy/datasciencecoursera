# %%
import pandas as pd

# %%
df = pd.read_csv('homeprices_onehot.csv')

# %%
dummies = pd.get_dummies(df.town)
dummies
# Out:
#     hebbal  koramangala  whitefield
# 0        0            1           0
# 1        0            1           0
# 2        0            1           0
# 3        0            1           0
# 4        0            1           0
# 5        1            0           0
# 6        1            0           0
# 7        1            0           0
# 8        1            0           0
# 9        0            0           1
# 10       0            0           1
# 11       0            0           1
# 12       0            0           1

# %%
merged = pd.concat([df,dummies],axis='columns')
merged
# Out:
#            town  area   price  hebbal  koramangala  whitefield
# 0   koramangala  2600  550000       0            1           0
# 1   koramangala  3000  565000       0            1           0
# 2   koramangala  3200  610000       0            1           0
# 3   koramangala  3600  680000       0            1           0
# 4   koramangala  4000  725000       0            1           0
# 5        hebbal  2600  585000       1            0           0
# 6        hebbal  2800  615000       1            0           0
# 7        hebbal  3300  650000       1            0           0
# 8        hebbal  3600  710000       1            0           0
# 9    whitefield  2600  575000       0            0           1
# 10   whitefield  2900  600000       0            0           1
# 11   whitefield  3100  620000       0            0           1
# 12   whitefield  3600  695000       0            0           1

# %%
final = merged.drop(['town'], axis='columns')
final
# Out:
#     area   price  hebbal  koramangala  whitefield
# 0   2600  550000       0            1           0
# 1   3000  565000       0            1           0
# 2   3200  610000       0            1           0
# 3   3600  680000       0            1           0
# 4   4000  725000       0            1           0
# 5   2600  585000       1            0           0
# 6   2800  615000       1            0           0
# 7   3300  650000       1            0           0
# 8   3600  710000       1            0           0
# 9   2600  575000       0            0           1
# 10  2900  600000       0            0           1
# 11  3100  620000       0            0           1
# 12  3600  695000       0            0           1

# %%
final = final.drop(['whitefield'],axis='columns')
final

# %%
#drop the target column/feature
X = final.drop(['price'],axis='columns')

# %%
y=final.price

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
model.predict(X)
# Out:
# array([539709.73984091, 590468.71640508, 615848.20468716, 666607.18125133,
#        717366.1578155 , 579723.71533005, 605103.20361213, 668551.92431735,
#        706621.15674048, 565396.15136531, 603465.38378844, 628844.87207052,
#        692293.59277574])

# %%
model.score(X,y)
# Out:
# 0.9573929037221871

# %%
model.predict([[2600,0,1]])
# Out:
# array([539709.73984091])

# %%
model.predict([[3600,0,0]])
# Out:
# array([692293.59277574])

# %%
pd.get_dummies(df)
# Out:
#     area   price  town_hebbal  town_koramangala  town_whitefield
# 0   2600  550000            0                 1                0
# 1   3000  565000            0                 1                0
# 2   3200  610000            0                 1                0
# 3   3600  680000            0                 1                0
# 4   4000  725000            0                 1                0
# 5   2600  585000            1                 0                0
# 6   2800  615000            1                 0                0
# 7   3300  650000            1                 0                0
# 8   3600  710000            1                 0                0
# 9   2600  575000            0                 0                1
# 10  2900  600000            0                 0                1
# 11  3100  620000            0                 0                1
# 12  3600  695000            0                 0                1

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
dfle = df
dfle.town = le.fit_transform(dfle.town)
dfle
# Out:
#     town  area   price
# 0      1  2600  550000
# 1      1  3000  565000
# 2      1  3200  610000
# 3      1  3600  680000
# 4      1  4000  725000
# 5      0  2600  585000
# 6      0  2800  615000
# 7      0  3300  650000
# 8      0  3600  710000
# 9      2  2600  575000
# 10     2  2900  600000
# 11     2  3100  620000
# 12     2  3600  695000

# %%
X = dfle[['town','area']].values
X
# Out:
# array([[   1, 2600],
#        [   1, 3000],
#        [   1, 3200],
#        [   1, 3600],
#        [   1, 4000],
#        [   0, 2600],
#        [   0, 2800],
#        [   0, 3300],
#        [   0, 3600],
#        [   2, 2600],
#        [   2, 2900],
#        [   2, 3100],
#        [   2, 3600]])

# %%
y = dfle.price.values
y
# Out:
# array([550000, 565000, 610000, 680000, 725000, 585000, 615000, 650000,
#        710000, 575000, 600000, 620000, 695000])

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
ct = ColumnTransformer([('town', OneHotEncoder(), [0])], remainder = 'passthrough')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-23-8ed9b26644c9> in <module>()
#       1 from sklearn.preprocessing import OneHotEncoder
# ----> 2 from sklearn.compose import ColumnTransformer
#       3 ct = ColumnTransformer([('town', OneHotEncoder(), [0])], remainder = 'passthrough')
#
# ModuleNotFoundError: No module named 'sklearn.compose'
